# %% [markdown]
# # Interactive Visualization in Jupyter with Bqplot and Interactive Widgets
#
# #### April 20th, San Francisco Python Meetup Group

# %% [markdown]
# ### This Tutorial    https://github.com/SylvainCorlay/tutorial
#
#
# Live demos:
#
# - [Interactive Widgets](Interactive Widgets.ipynb)
# - [bqplot](Bqplot.ipynb)
# - [pythreejs](PyThreejs.ipynb)
# - [Leaflet](LeafletGeoJSON.ipynb)
#     - [Leaflet - 2](LeafletDraw.ipynb)
# - [GIS](Fly.ipynb)

# %% [markdown]
# ### *The Purpose of Computing is Insight, not Numbers* -- Richard Hamming
#
# ### *Literate programming* -- Donald Knuth
# Literate programming is an approach to programming introduced by Donald Knuth in which a program is given as an explanation of the program logic in a natural language, such as English, interspersed with snippets of macros and traditional source code, from which a compilable source code can be generated
